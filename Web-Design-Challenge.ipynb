# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
cities_df = pd.read_csv("Resources/cities.csv")
cities_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
len(cities_df)
# Out:
# 547

# %%
cities_df.to_html("Resources/cities_data.html")

# %% [markdown]
# ## Plotting the Data

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Incorporate the other graph properties
# Save the figure
# Show plot
plot_lat = cities_df["Lat"]
plot_temp = cities_df["Max Temp"]

plt.scatter(plot_lat,plot_temp)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.savefig('Images/plot_latitude_vs_temp')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plot_humidity = cities_df["Humidity"]

plt.scatter(plot_lat,plot_humidity)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('Images/plot_latitude_vs_humidity')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plot_cloudiness = cities_df["Cloudiness"]

plt.scatter(plot_lat,plot_cloudiness)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('Images/plot_latitude_vs_cloudiness')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
wind_speed = cities_df["Wind Speed"]

plt.scatter(plot_lat,wind_speed)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('Images/plot_latitude_vs_windspeed')
plt.show()
